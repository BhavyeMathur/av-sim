# %%
from ev_sim.yaml import *
import subprocess

# %%
experiment = "ann-arbor-strategy-speed-comparison"

# %%
configs = generate_runs_from_experiment_yaml(f"experiments/{experiment}.yaml")

subprocess.run(["cmake", "--build", "cmake-build-release", "--target", "sim", "-j", "8"], check=True)
subprocess.run(["./sim", f"runs/{experiment}/manifest.txt"], check=True)
# Out:
# Generated 14 runs
#
# [ 12%] Built target tqdm
# [ 25%] Built target h3
# [ 29%] Built target pandas
# [ 70%] Built target yaml-cpp
# [ 70%] Building CXX object CMakeFiles/sim.dir/src/main.cpp.o
# [ 70%] Linking CXX executable /Users/bhavyemathur/Desktop/Academics/College/UMich/IOE/ev-sim/sim
# [100%] Built target sim
# ...running 14 experiments with up to 8 concurrent runs
# reading data/requests/ann-arbor.parquet
# reading data/requests/ann-arbor.parquet
# reading data/requests/ann-arbor.parquet
# reading data/requests/ann-arbor.parquet
# reading data/requests/ann-arbor.parquet
# reading reading data/requests/ann-arbor.parquet
# data/requests/ann-arbor.parquet
# reading data/requests/ann-arbor.parquet
# reading data/riders/ann-arbor-10000.parquet
# [#######                                           ]  14% | [11s<67s]
# reading data/riders/ann-arbor-15000.parquet
# [                                                  ]   0% | [ 0s< 0s]
# reading data/riders/ann-arbor-10000.parquet
# ...
