# %%
from ev_sim.yaml import *

# %%
configs = generate_runs_from_experiment_yaml("experiments/ann-arbor-strategy-speed-comparison.yaml",
                                             output_root="runs")
print(f"Generated {len(configs)} runs\n")
# Out:
# Generated 14 runs

# %%
configs[0]
# Out:
# {'description': 'Compare the performance of global, greedy-h3, and bounded-h3 strategies\n',
#  'sim': {'length_s': 604800,
#   'requests_file': 'data/requests/ann-arbor.parquet',
#   'h3_resolution': 7,
#   'riders_file': 'data/riders/ann-arbor-10000.parquet'},
#  'policy': {'charging': 'disable', 'matching': 'global'},
#  'fleet': {'frac_2_seater': 0.0, 'frac_4_seater': 0.0, 'fleet_size': 10000}}
