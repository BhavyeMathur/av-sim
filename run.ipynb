# %%
import ev_sim
from ev_sim.constants import RUN_DB

# %%
experiment = "ann-arbor-strategy-speed-comparison"
experiment = "ann-arbor-charging-comparison"
experiment = "ann-arbor-fleet-sizing"
experiment = "ann-arbor-15k-vehicles"
# experiment = "ann-arbor-vehicle-batching"
# experiment = "washtenaw-fleet-sizing"
# experiment = "washtenaw-60k-vehicles"
# experiment = "detroit-fleet-sizing"
# experiment = "se-michigan-1M-vehicles"

configs = ev_sim.generate_runs_from_yaml(f"experiments/{experiment}.yaml")

# %%
ev_sim.build_and_run("sim", f"runs/{experiment}/manifest.txt")
c = ev_sim.compute_pending_stats(RUN_DB, ev_sim.compute_stats)
print(f"completed {c} runs")

# %%
c = ev_sim.recompute_experiment_stats(RUN_DB, experiment, ev_sim.compute_stats)
print(f"completed {c} runs")
# Out:
# completed 1 runs

# %%
db = ev_sim.RunDB(RUN_DB)

df = (db.query()
      .experiment("ann-arbor-15k-vehicles")
      # .experiment("washtenaw-60k-vehicles")
      #.experiment("se-michigan-1M-vehicles")
      # .where_config("sim.length_s", "=", 24 * 3600 * 7)
      .load())

df[["duration_ms", "total", "dropped", "service_level", "mean_response_time", "mean_pickup_time", "mean_fm_dist",
    "idle_pct", "q1_response_time", "pct90_response_time", "pct95_response_time", "policy.matching", "fleet.fleet_size",
    "sim.h3_resolution"]]
# Out:
#      duration_ms      total  dropped  service_level  mean_response_time  \
# id
# 79        101252  4109205.0      6.0      99.999854            3.211981
# 80         98085  4109205.0      6.0      99.999854            3.211981
# 81        123638  4109205.0      3.0      99.999927            3.006706
# 82        111039  4109205.0      3.0      99.999927            3.007936
# 83         70359  4109205.0      0.0     100.000000            2.989104
# 84         41219  4109205.0      0.0     100.000000            3.035224
# 85         42915  4109205.0      0.0     100.000000            2.997627
# 86        151078  4109205.0      0.0     100.000000            2.997627
# 87        155851  4109205.0      0.0     100.000000            2.997627
# 88         42591  4109205.0      0.0     100.000000            2.997627
# 89         43469  4109205.0      0.0     100.000000            2.997627
# 90         43028  4109205.0      0.0     100.000000            2.997627
# 91        155593  4109205.0      0.0     100.000000            2.997627
# 92         42828  4109205.0      0.0     100.000000            2.997627
# 98         36130  4109205.0      0.0     100.000000            3.093767
# 99         36349  4109205.0      0.0     100.000000            3.093767
# 100        58233  4109205.0      0.0     100.000000            3.015761
# 101        43407  4109205.0      0.0     100.000000            2.997627
# 102        34390  4109205.0      0.0     100.000000            2.995693
# 104        41322  4109205.0      0.0     100.000000            3.005096
# 105        34773  4109205.0      0.0     100.000000            2.995693
# 106        36005  4109205.0      0.0     100.000000            2.995693
# 107        34712  4109205.0      0.0     100.000000            2.995693
# 108        34435  4109205.0      0.0     100.000000            2.995693
# 110        29216  4109205.0      0.0     100.000000            3.029989
# 113        28549  4109205.0      0.0     100.000000            3.029989
# 114        28485  4109205.0      0.0     100.000000            3.029989
# 115        28431  4109205.0      0.0     100.000000            3.029989
# 119        28212  4109205.0      0.0     100.000000            3.029989
# 127       950932        NaN      NaN            NaN                 NaN
# 128         9749        NaN      NaN            NaN                 NaN
# 130        10245  4109205.0  75140.0      98.171422           12.561165
# 131        21898  4109205.0      0.0     100.000000            2.905676
#
#      mean_pickup_time  mean_fm_dist   idle_pct  q1_response_time  \
# id
# 79                2.0      1.014284  60.949396          1.016667
# 80                2.0      1.014284  60.949396          1.016667
# 81                2.0      1.002119  61.122089          1.033333
# 82                2.0      1.002154  61.075984          1.016667
# 83                2.0      0.998729  57.193465          1.016667
# 84                2.0      1.000766  57.184549          1.016667
# 85                2.0      0.998454  57.138002          1.016667
# 86                2.0      0.998454  57.138002          1.016667
# 87                2.0      0.998454  57.138002          1.016667
# 88                2.0      0.998454  57.138002          1.016667
# 89                2.0      0.998454  57.138002          1.016667
# 90                2.0      0.998454  57.138002          1.016667
# 91                2.0      0.998454  57.138002          1.016667
# 92                2.0      0.998454  57.138002          1.016667
# 98                2.0      0.999322  57.205938          1.016667
# 99                2.0      0.999322  57.205938          1.016667
# 100               2.0      0.998462  57.204516          1.016667
# 101               2.0      0.998454  57.138002          1.016667
# 102               2.0      1.009403  57.105858          1.016667
# 104               2.0      1.000856  57.063468          1.016667
# 105               2.0      1.009403  57.105858          1.016667
# 106               2.0      1.009403  57.105858          1.016667
# 107               2.0      1.009403  57.105858          1.016667
# 108               2.0      1.009403  57.105858          1.016667
# 110               2.0      1.074203  57.488029          1.250000
# 113               2.0      1.074203  57.488029          1.250000
# 114               2.0      1.074203  57.488029          1.250000
# 115               2.0      1.074203  57.488029          1.250000
# 119               2.0      1.074203  57.488029          1.250000
# 127               NaN           NaN        NaN               NaN
# 128               NaN           NaN        NaN               NaN
# 130               2.0      1.516555  56.315662          1.983333
# 131               2.0      1.063006  61.392435          1.233333
#
#      pct90_response_time  pct95_response_time policy.matching  \
# id
# 79              8.366667             9.733333      bounded-h3
# 80              8.366667             9.733333      bounded-h3
# 81              7.866667             8.933333      bounded-h3
# 82              7.883333             8.950000      bounded-h3
# 83              7.850000             8.916667      bounded-h3
# 84              8.033333             9.250000      bounded-h3
# 85              7.883333             9.000000      bounded-h3
# 86              7.883333             9.000000      bounded-h3
# 87              7.883333             9.000000      bounded-h3
# 88              7.883333             9.000000      bounded-h3
# 89              7.883333             9.000000      bounded-h3
# 90              7.883333             9.000000      bounded-h3
# 91              7.883333             9.000000      bounded-h3
# 92              7.883333             9.000000      bounded-h3
# 98              8.250000             9.466667      bounded-h3
# 99              8.250000             9.466667      bounded-h3
# 100             7.966667             9.083333      bounded-h3
# 101             7.883333             9.000000      bounded-h3
# 102             7.883333             9.000000      bounded-h3
# 104             7.900000             9.016667      bounded-h3
# 105             7.883333             9.000000      bounded-h3
# 106             7.883333             9.000000      bounded-h3
# 107             7.883333             9.000000      bounded-h3
# 108             7.883333             9.000000      bounded-h3
# 110             7.800000             8.966667      bounded-h3
# 113             7.800000             8.966667      bounded-h3
# 114             7.800000             8.966667      bounded-h3
# 115             7.800000             8.966667      bounded-h3
# 119             7.800000             8.966667      bounded-h3
# 127                  NaN                  NaN      bounded-h3
# 128                  NaN                  NaN      bounded-h3
# 130            21.966667            26.533333      bounded-h3
# 131             7.516667             8.750000      bounded-h3
#
#     fleet.fleet_size sim.h3_resolution
# id
# 79             15000                 8
# 80             15000                 8
# 81             15000                 7
# 82             15000                 8
# 83             15000                 8
# 84             15000                 8
# 85             15000                 8
# 86             15000                 8
# 87             15000                 8
# 88             15000                 8
# 89             15000                 8
# 90             15000                 8
# 91             15000                 8
# 92             15000                 8
# 98             15000                 8
# 99             15000                 8
# 100            15000                 8
# 101            15000                 8
# 102            15000                 8
# 104            15000                 8
# 105            15000                 8
# 106            15000                 8
# 107            15000                 8
# 108            15000                 8
# 110            15000                 8
# 113            15000                 8
# 114            15000                 8
# 115            15000                 8
# 119            15000                 8
# 127            15000                 8
# 128            15000                 8
# 130            15000                 8
# 131            15000                 8
