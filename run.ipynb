# %%
import ev_sim
from ev_sim.constants import RUN_DB

# %%
experiment = "ann-arbor-strategy-speed-comparison"
experiment = "ann-arbor-charging-comparison"
experiment = "ann-arbor-fleet-sizing"
experiment = "ann-arbor-15k-vehicles"
# experiment = "ann-arbor-vehicle-batching"
# experiment = "washtenaw-fleet-sizing"
# experiment = "washtenaw-60k-vehicles"
# experiment = "detroit-fleet-sizing"
# experiment = "se-michigan-1M-vehicles"

configs = ev_sim.generate_runs_from_yaml(f"experiments/{experiment}.yaml")

# %%
ev_sim.build_and_run("sim", f"runs/{experiment}/manifest.txt")
c = ev_sim.compute_pending_stats(RUN_DB, ev_sim.compute_stats)
print(f"completed {c} runs")
# Out:
# >>> Building...
# [0/2] Re-checking globbed directories...
# ninja: no work to do.
# >>> Running...
# reading data/requests/ann-arbor.parquet
# reading data/riders/ann-arbor-15000.parquet
# progress:   0% | elapsed=0s remaining=0s
# progress:   0% | elapsed=0s remaining=0s
# progress:   0% | elapsed=0s remaining=0s
# progress:   1% | elapsed=0s remaining=0s
# progress:   1% | elapsed=0s remaining=0s
# progress:   2% | elapsed=0s remaining=0s
# progress:   2% | elapsed=0s remaining=0s
# progress:   3% | elapsed=0s remaining=0s
# progress:   3% | elapsed=0s remaining=0s
# progress:   4% | elapsed=0s remaining=0s
# progress:   4% | elapsed=0s remaining=0s
# progress:   5% | elapsed=1s remaining=19s
# progress:   5% | elapsed=1s remaining=19s
# progress:   6% | elapsed=1s remaining=15s
# progress:   6% | elapsed=1s remaining=15s
# progress:   7% | elapsed=1s remaining=13s
# progress:   7% | elapsed=1s remaining=13s
# progress:   8% | elapsed=1s remaining=11s
# progress:   8% | elapsed=1s remaining=11s
# progress:   9% | elapsed=1s remaining=10s
# progress:   9% | elapsed=1s remaining=10s
# progress:  10% | elapsed=1s remaining=9s
# progress:  10% | elapsed=1s remaining=9s
# progress:  11% | elapsed=1s remaining=8s
# progress:  11% | elapsed=1s remaining=8s
# progress:  11% | elapsed=2s remaining=16s
# progress:  12% | elapsed=2s remaining=14s
# progress:  12% | elapsed=2s remaining=14s
# progress:  13% | elapsed=2s remaining=13s
# progress:  13% | elapsed=2s remaining=13s
# progress:  14% | elapsed=2s remaining=12s
# progress:  14% | elapsed=2s remaining=12s
# progress:  15% | elapsed=2s remaining=11s
# progress:  15% | elapsed=2s remaining=11s
# progress:  16% | elapsed=2s remaining=10s
# progress:  16% | elapsed=2s remaining=10s
# progress:  17% | elapsed=2s remaining=9s
# progress:  17% | elapsed=2s remaining=9s
# progress:  18% | elapsed=2s remaining=9s
# progress:  18% | elapsed=3s remaining=13s
# progress:  19% | elapsed=3s remaining=12s
# progress:  19% | elapsed=3s remaining=12s
# progress:  20% | elapsed=3s remaining=12s
# progress:  20% | elapsed=3s remaining=12s
# progress:  21% | elapsed=3s remaining=11s
# progress:  21% | elapsed=3s remaining=11s
# progress:  22% | elapsed=4s remaining=14s
# progress:  22% | elapsed=4s remaining=14s
# progress:  23% | elapsed=4s remaining=13s
# progress:  23% | elapsed=4s remaining=13s
# progress:  24% | elapsed=4s remaining=12s
# progress:  24% | elapsed=4s remaining=12s
# progress:  24% | elapsed=4s remaining=12s
# progress:  25% | elapsed=4s remaining=12s
# progress:  25% | elapsed=4s remaining=12s
# progress:  26% | elapsed=4s remaining=11s
# progress:  26% | elapsed=4s remaining=11s
# progress:  27% | elapsed=4s remaining=10s
# progress:  27% | elapsed=4s remaining=10s
# progress:  28% | elapsed=5s remaining=12s
# progress:  28% | elapsed=5s remaining=12s
# progress:  29% | elapsed=5s remaining=12s
# progress:  29% | elapsed=5s remaining=12s
# progress:  30% | elapsed=5s remaining=11s
# progress:  30% | elapsed=5s remaining=11s
# progress:  31% | elapsed=5s remaining=11s
# progress:  31% | elapsed=5s remaining=11s
# progress:  32% | elapsed=5s remaining=10s
# progress:  32% | elapsed=5s remaining=10s
# progress:  33% | elapsed=5s remaining=10s
# progress:  33% | elapsed=5s remaining=10s
# progress:  34% | elapsed=5s remaining=9s
# progress:  34% | elapsed=5s remaining=9s
# progress:  35% | elapsed=6s remaining=11s
# progress:  35% | elapsed=6s remaining=11s
# progress:  36% | elapsed=6s remaining=10s
# progress:  36% | elapsed=6s remaining=10s
# progress:  36% | elapsed=6s remaining=10s
# progress:  37% | elapsed=6s remaining=10s
# progress:  37% | elapsed=6s remaining=10s
# progress:  38% | elapsed=6s remaining=9s
# progress:  38% | elapsed=6s remaining=9s
# progress:  39% | elapsed=7s remaining=10s
# progress:  39% | elapsed=7s remaining=10s
# progress:  40% | elapsed=7s remaining=10s
# progress:  40% | elapsed=7s remaining=10s
# progress:  41% | elapsed=7s remaining=10s
# progress:  41% | elapsed=7s remaining=10s
# progress:  42% | elapsed=7s remaining=9s
# progress:  42% | elapsed=7s remaining=9s
# progress:  43% | elapsed=7s remaining=9s
# progress:  43% | elapsed=7s remaining=9s
# progress:  44% | elapsed=7s remaining=8s
# progress:  44% | elapsed=7s remaining=8s
# progress:  45% | elapsed=8s remaining=9s
# progress:  45% | elapsed=8s remaining=9s
# progress:  46% | elapsed=8s remaining=9s
# progress:  46% | elapsed=8s remaining=9s
# progress:  47% | elapsed=8s remaining=9s
# progress:  47% | elapsed=8s remaining=9s
# progress:  48% | elapsed=8s remaining=8s
# progress:  48% | elapsed=8s remaining=8s
# progress:  49% | elapsed=8s remaining=8s
# progress:  49% | elapsed=8s remaining=8s
# progress:  50% | elapsed=8s remaining=8s
# progress:  50% | elapsed=8s remaining=8s
# progress:  50% | elapsed=8s remaining=8s
# progress:  51% | elapsed=9s remaining=8s
# progress:  51% | elapsed=9s remaining=8s
# progress:  52% | elapsed=9s remaining=8s
# progress:  52% | elapsed=9s remaining=8s
# progress:  53% | elapsed=9s remaining=7s
# progress:  53% | elapsed=9s remaining=7s
# progress:  54% | elapsed=9s remaining=7s
# progress:  54% | elapsed=9s remaining=7s
# progress:  55% | elapsed=9s remaining=7s
# progress:  55% | elapsed=9s remaining=7s
# progress:  56% | elapsed=9s remaining=7s
# progress:  56% | elapsed=10s remaining=7s
# progress:  57% | elapsed=10s remaining=7s
# progress:  57% | elapsed=10s remaining=7s
# progress:  58% | elapsed=10s remaining=7s
# progress:  58% | elapsed=10s remaining=7s
# progress:  59% | elapsed=10s remaining=6s
# progress:  59% | elapsed=10s remaining=6s
# progress:  60% | elapsed=10s remaining=6s
# progress:  60% | elapsed=10s remaining=6s
# progress:  61% | elapsed=10s remaining=6s
# progress:  61% | elapsed=11s remaining=7s
# progress:  61% | elapsed=11s remaining=7s
# progress:  62% | elapsed=11s remaining=6s
# progress:  63% | elapsed=11s remaining=6s
# progress:  63% | elapsed=11s remaining=6s
# progress:  63% | elapsed=11s remaining=6s
# progress:  64% | elapsed=11s remaining=6s
# progress:  64% | elapsed=11s remaining=6s
# progress:  65% | elapsed=11s remaining=5s
# progress:  65% | elapsed=11s remaining=5s
# progress:  66% | elapsed=11s remaining=5s
# progress:  66% | elapsed=11s remaining=5s
# progress:  67% | elapsed=11s remaining=5s
# progress:  67% | elapsed=12s remaining=5s
# progress:  68% | elapsed=12s remaining=5s
# progress:  68% | elapsed=12s remaining=5s
# progress:  69% | elapsed=12s remaining=5s
# progress:  69% | elapsed=12s remaining=5s
# progress:  70% | elapsed=12s remaining=5s
# progress:  70% | elapsed=12s remaining=5s
# progress:  71% | elapsed=12s remaining=4s
# progress:  71% | elapsed=12s remaining=4s
# progress:  72% | elapsed=12s remaining=4s
# progress:  72% | elapsed=12s remaining=4s
# progress:  73% | elapsed=12s remaining=4s
# progress:  73% | elapsed=12s remaining=4s
# progress:  73% | elapsed=12s remaining=4s
# progress:  74% | elapsed=13s remaining=4s
# progress:  74% | elapsed=13s remaining=4s
# progress:  75% | elapsed=13s remaining=4s
# progress:  75% | elapsed=13s remaining=4s
# progress:  76% | elapsed=13s remaining=4s
# progress:  76% | elapsed=13s remaining=4s
# progress:  77% | elapsed=13s remaining=3s
# progress:  77% | elapsed=14s remaining=4s
# progress:  78% | elapsed=14s remaining=3s
# progress:  78% | elapsed=14s remaining=3s
# progress:  79% | elapsed=14s remaining=3s
# progress:  79% | elapsed=14s remaining=3s
# progress:  80% | elapsed=14s remaining=3s
# progress:  80% | elapsed=14s remaining=3s
# progress:  81% | elapsed=14s remaining=3s
# progress:  81% | elapsed=14s remaining=3s
# progress:  82% | elapsed=14s remaining=3s
# progress:  82% | elapsed=14s remaining=3s
# progress:  83% | elapsed=14s remaining=2s
# progress:  83% | elapsed=14s remaining=2s
# progress:  84% | elapsed=14s remaining=2s
# progress:  84% | elapsed=14s remaining=2s
# progress:  85% | elapsed=14s remaining=2s
# progress:  85% | elapsed=14s remaining=2s
# progress:  86% | elapsed=14s remaining=2s
# progress:  86% | elapsed=14s remaining=2s
# progress:  86% | elapsed=14s remaining=2s
# progress:  87% | elapsed=15s remaining=2s
# progress:  87% | elapsed=15s remaining=2s
# progress:  88% | elapsed=15s remaining=2s
# progress:  88% | elapsed=15s remaining=2s
# progress:  89% | elapsed=15s remaining=1s
# progress:  89% | elapsed=15s remaining=1s
# progress:  90% | elapsed=15s remaining=1s
# progress:  90% | elapsed=15s remaining=1s
# progress:  91% | elapsed=15s remaining=1s
# progress:  91% | elapsed=15s remaining=1s
# progress:  92% | elapsed=15s remaining=1s
# progress:  92% | elapsed=15s remaining=1s
# progress:  93% | elapsed=16s remaining=1s
# progress:  93% | elapsed=16s remaining=1s
# progress:  94% | elapsed=16s remaining=1s
# progress:  94% | elapsed=16s remaining=1s
# progress:  95% | elapsed=16s remaining=0s
# progress:  95% | elapsed=16s remaining=0s
# progress:  96% | elapsed=16s remaining=0s
# progress:  96% | elapsed=16s remaining=0s
# progress:  97% | elapsed=16s remaining=0s
# progress:  97% | elapsed=16s remaining=0s
# progress:  98% | elapsed=16s remaining=0s
# progress:  98% | elapsed=17s remaining=0s
# progress:  99% | elapsed=17s remaining=0s
# progress:  99% | elapsed=17s remaining=0s
# progress: 100% | elapsed=17s remaining=0s
#
# ...saving fleet statistics (count=674)
# ...saving rider statistics (count=16681430)
# ...saving statistics (count=4109205)
# ---------------------------------------------------------------------------
# ArrowInvalid                              Traceback (most recent call last)
# Cell In[20], line 2
#       1 ev_sim.build_and_run("sim", f"runs/{experiment}/manifest.txt")
# ----> 2 c = ev_sim.compute_pending_stats(RUN_DB, ev_sim.compute_stats)
#       3 print(f"completed {c} runs")
#
# File ~/Desktop/College/UMich/IOE/ev-sim/ev_sim/database.py:163, in compute_pending_stats(db_path, compute_stats)
#     160 finally:
#     161     conn.close()
# --> 163 return compute_statistics_for_run_ids(db_path, run_ids, compute_stats)
#
# File ~/Desktop/College/UMich/IOE/ev-sim/ev_sim/database.py:143, in compute_statistics_for_run_ids(db_path, run_ids, compute_stats)
#     140 runs = conn.execute(query, run_ids).fetchall()
#     142 for run in runs:
# --> 143     stats = compute_stats(run)
#     144     if not isinstance(stats, dict):
#     145         raise TypeError(f"compute_stats did not return a dict")
#
# File ~/Desktop/College/UMich/IOE/ev-sim/ev_sim/stats.py:123, in compute_stats(run)
#     122 def compute_stats(run):
# --> 123     requests, fleet_output, waypoints, vehicle_state_durations = load_results(run)
#     125     stats = compute_request_statistics(requests)
#     126     if waypoints is not None:
#
# File ~/Desktop/College/UMich/IOE/ev-sim/ev_sim/stats.py:45, in load_results(run)
#      42     fleet_output = None
#      44 try:
# ---> 45     waypoints = pd.read_parquet(f"{output_dir}/waypoints.parquet")
#      46     vehicle_state_durations = compute_vehicle_state_durations(waypoints)
#      47 except FileNotFoundError:
#
# File ~/Desktop/College/UMich/IOE/ev-sim/venv/lib/python3.13/site-packages/pandas/io/parquet.py:669, in read_parquet(path, engine, columns, storage_options, use_nullable_dtypes, dtype_backend, filesystem, filters, **kwargs)
#     666     use_nullable_dtypes = False
#     667 check_dtype_backend(dtype_backend)
# --> 669 return impl.read(
#     670     path,
#     671     columns=columns,
#     672     filters=filters,
#     673     storage_options=storage_options,
#     674     use_nullable_dtypes=use_nullable_dtypes,
#     675     dtype_backend=dtype_backend,
#     676     filesystem=filesystem,
#     677     **kwargs,
#     678 )
#
# File ~/Desktop/College/UMich/IOE/ev-sim/venv/lib/python3.13/site-packages/pandas/io/parquet.py:265, in PyArrowImpl.read(self, path, columns, filters, use_nullable_dtypes, dtype_backend, storage_options, filesystem, **kwargs)
#     258 path_or_handle, handles, filesystem = _get_path_or_handle(
#     259     path,
#     260     filesystem,
#     261     storage_options=storage_options,
#     262     mode="rb",
#     263 )
#     264 try:
# --> 265     pa_table = self.api.parquet.read_table(
#     266         path_or_handle,
#     267         columns=columns,
#     268         filesystem=filesystem,
#     269         filters=filters,
#     270         **kwargs,
#     271     )
#     273     with catch_warnings():
#     274         filterwarnings(
#     275             "ignore",
#     276             "make_block is deprecated",
#     277             DeprecationWarning,
#     278         )
#
# File ~/Desktop/College/UMich/IOE/ev-sim/venv/lib/python3.13/site-packages/pyarrow/parquet/core.py:1774, in read_table(source, columns, use_threads, schema, use_pandas_metadata, read_dictionary, memory_map, buffer_size, partitioning, filesystem, filters, ignore_prefixes, pre_buffer, coerce_int96_timestamp_unit, decryption_properties, thrift_string_size_limit, thrift_container_size_limit, page_checksum_verification)
#    1764 def read_table(source, *, columns=None, use_threads=True,
#    1765                schema=None, use_pandas_metadata=False, read_dictionary=None,
#    1766                memory_map=False, buffer_size=0, partitioning="hive",
#    (...)   1770                thrift_container_size_limit=None,
#    1771                page_checksum_verification=False):
#    1773     try:
# -> 1774         dataset = ParquetDataset(
#    1775             source,
#    1776             schema=schema,
#    1777             filesystem=filesystem,
#    1778             partitioning=partitioning,
#    1779             memory_map=memory_map,
#    1780             read_dictionary=read_dictionary,
#    1781             buffer_size=buffer_size,
#    1782             filters=filters,
#    1783             ignore_prefixes=ignore_prefixes,
#    1784             pre_buffer=pre_buffer,
#    1785             coerce_int96_timestamp_unit=coerce_int96_timestamp_unit,
#    1786             decryption_properties=decryption_properties,
#    1787             thrift_string_size_limit=thrift_string_size_limit,
#    1788             thrift_container_size_limit=thrift_container_size_limit,
#    1789             page_checksum_verification=page_checksum_verification,
#    1790         )
#    1791     except ImportError:
#    1792         # fall back on ParquetFile for simple cases when pyarrow.dataset
#    1793         # module is not available
#    1794         if filters is not None:
#
# File ~/Desktop/College/UMich/IOE/ev-sim/venv/lib/python3.13/site-packages/pyarrow/parquet/core.py:1350, in ParquetDataset.__init__(self, path_or_paths, filesystem, schema, filters, read_dictionary, memory_map, buffer_size, partitioning, ignore_prefixes, pre_buffer, coerce_int96_timestamp_unit, decryption_properties, thrift_string_size_limit, thrift_container_size_limit, page_checksum_verification)
#    1346 if single_file is not None:
#    1347     fragment = parquet_format.make_fragment(single_file, filesystem)
#    1349     self._dataset = ds.FileSystemDataset(
# -> 1350         [fragment], schema=schema or fragment.physical_schema,
#    1351         format=parquet_format,
#    1352         filesystem=fragment.filesystem
#    1353     )
#    1354     return
#    1356 # check partitioning to enable dictionary encoding
#
# File ~/Desktop/College/UMich/IOE/ev-sim/venv/lib/python3.13/site-packages/pyarrow/_dataset.pyx:1473, in pyarrow._dataset.Fragment.physical_schema.__get__()
#
# File ~/Desktop/College/UMich/IOE/ev-sim/venv/lib/python3.13/site-packages/pyarrow/error.pxi:155, in pyarrow.lib.pyarrow_internal_check_status()
#
# File ~/Desktop/College/UMich/IOE/ev-sim/venv/lib/python3.13/site-packages/pyarrow/error.pxi:92, in pyarrow.lib.check_status()
#
# ArrowInvalid: Could not open Parquet input source '<Buffer>': Parquet magic bytes not found in footer. Either the file is corrupted or this is not a parquet file.

# %%
c = ev_sim.recompute_experiment_stats(RUN_DB, experiment, ev_sim.compute_stats)
print(f"completed {c} runs")
# Out:
# completed 1 runs

# %%
db = ev_sim.RunDB(RUN_DB)

df = (db.query()
      .experiment("ann-arbor-15k-vehicles")
      # .experiment("washtenaw-60k-vehicles")
      #.experiment("se-michigan-1M-vehicles")
      # .where_config("sim.length_s", "=", 24 * 3600 * 7)
      .load())

df[["duration_ms", "total", "dropped", "service_level", "mean_response_time", "mean_pickup_time", "mean_fm_dist",
    "idle_pct", "q1_response_time", "pct90_response_time", "pct95_response_time", "policy.matching", "fleet.fleet_size",
    "sim.h3_resolution"]]
# Out:
#      duration_ms      total  dropped  service_level  mean_response_time  \
# id
# 79        101252  4109205.0      6.0      99.999854            3.211981
# 80         98085  4109205.0      6.0      99.999854            3.211981
# 81        123638  4109205.0      3.0      99.999927            3.006706
# 82        111039  4109205.0      3.0      99.999927            3.007936
# 83         70359  4109205.0      0.0     100.000000            2.989104
# 84         41219  4109205.0      0.0     100.000000            3.035224
# 85         42915  4109205.0      0.0     100.000000            2.997627
# 86        151078  4109205.0      0.0     100.000000            2.997627
# 87        155851  4109205.0      0.0     100.000000            2.997627
# 88         42591  4109205.0      0.0     100.000000            2.997627
# 89         43469  4109205.0      0.0     100.000000            2.997627
# 90         43028  4109205.0      0.0     100.000000            2.997627
# 91        155593  4109205.0      0.0     100.000000            2.997627
# 92         42828  4109205.0      0.0     100.000000            2.997627
# 98         36130  4109205.0      0.0     100.000000            3.093767
# 99         36349  4109205.0      0.0     100.000000            3.093767
# 100        58233  4109205.0      0.0     100.000000            3.015761
# 101        43407  4109205.0      0.0     100.000000            2.997627
# 102        34390  4109205.0      0.0     100.000000            2.995693
# 104        41322  4109205.0      0.0     100.000000            3.005096
# 105        34773  4109205.0      0.0     100.000000            2.995693
# 106        36005  4109205.0      0.0     100.000000            2.995693
# 107        34712  4109205.0      0.0     100.000000            2.995693
# 108        34435  4109205.0      0.0     100.000000            2.995693
# 110        29216  4109205.0      0.0     100.000000            3.029989
# 113        28549  4109205.0      0.0     100.000000            3.029989
# 114        28485  4109205.0      0.0     100.000000            3.029989
# 115        28431  4109205.0      0.0     100.000000            3.029989
# 119        28212  4109205.0      0.0     100.000000            3.029989
# 127       950932        NaN      NaN            NaN                 NaN
# 128         9749        NaN      NaN            NaN                 NaN
# 130        10245  4109205.0  75140.0      98.171422           12.561165
# 131        21898  4109205.0      0.0     100.000000            2.905676
#
#      mean_pickup_time  mean_fm_dist   idle_pct  q1_response_time  \
# id
# 79                2.0      1.014284  60.949396          1.016667
# 80                2.0      1.014284  60.949396          1.016667
# 81                2.0      1.002119  61.122089          1.033333
# 82                2.0      1.002154  61.075984          1.016667
# 83                2.0      0.998729  57.193465          1.016667
# 84                2.0      1.000766  57.184549          1.016667
# 85                2.0      0.998454  57.138002          1.016667
# 86                2.0      0.998454  57.138002          1.016667
# 87                2.0      0.998454  57.138002          1.016667
# 88                2.0      0.998454  57.138002          1.016667
# 89                2.0      0.998454  57.138002          1.016667
# 90                2.0      0.998454  57.138002          1.016667
# 91                2.0      0.998454  57.138002          1.016667
# 92                2.0      0.998454  57.138002          1.016667
# 98                2.0      0.999322  57.205938          1.016667
# 99                2.0      0.999322  57.205938          1.016667
# 100               2.0      0.998462  57.204516          1.016667
# 101               2.0      0.998454  57.138002          1.016667
# 102               2.0      1.009403  57.105858          1.016667
# 104               2.0      1.000856  57.063468          1.016667
# 105               2.0      1.009403  57.105858          1.016667
# 106               2.0      1.009403  57.105858          1.016667
# 107               2.0      1.009403  57.105858          1.016667
# 108               2.0      1.009403  57.105858          1.016667
# 110               2.0      1.074203  57.488029          1.250000
# 113               2.0      1.074203  57.488029          1.250000
# 114               2.0      1.074203  57.488029          1.250000
# 115               2.0      1.074203  57.488029          1.250000
# 119               2.0      1.074203  57.488029          1.250000
# 127               NaN           NaN        NaN               NaN
# 128               NaN           NaN        NaN               NaN
# 130               2.0      1.516555  56.315662          1.983333
# 131               2.0      1.063006  61.392435          1.233333
#
#      pct90_response_time  pct95_response_time policy.matching  \
# id
# 79              8.366667             9.733333      bounded-h3
# 80              8.366667             9.733333      bounded-h3
# 81              7.866667             8.933333      bounded-h3
# 82              7.883333             8.950000      bounded-h3
# 83              7.850000             8.916667      bounded-h3
# 84              8.033333             9.250000      bounded-h3
# 85              7.883333             9.000000      bounded-h3
# 86              7.883333             9.000000      bounded-h3
# 87              7.883333             9.000000      bounded-h3
# 88              7.883333             9.000000      bounded-h3
# 89              7.883333             9.000000      bounded-h3
# 90              7.883333             9.000000      bounded-h3
# 91              7.883333             9.000000      bounded-h3
# 92              7.883333             9.000000      bounded-h3
# 98              8.250000             9.466667      bounded-h3
# 99              8.250000             9.466667      bounded-h3
# 100             7.966667             9.083333      bounded-h3
# 101             7.883333             9.000000      bounded-h3
# 102             7.883333             9.000000      bounded-h3
# 104             7.900000             9.016667      bounded-h3
# 105             7.883333             9.000000      bounded-h3
# 106             7.883333             9.000000      bounded-h3
# 107             7.883333             9.000000      bounded-h3
# 108             7.883333             9.000000      bounded-h3
# 110             7.800000             8.966667      bounded-h3
# 113             7.800000             8.966667      bounded-h3
# 114             7.800000             8.966667      bounded-h3
# 115             7.800000             8.966667      bounded-h3
# 119             7.800000             8.966667      bounded-h3
# 127                  NaN                  NaN      bounded-h3
# 128                  NaN                  NaN      bounded-h3
# 130            21.966667            26.533333      bounded-h3
# 131             7.516667             8.750000      bounded-h3
#
#     fleet.fleet_size sim.h3_resolution
# id
# 79             15000                 8
# 80             15000                 8
# 81             15000                 7
# 82             15000                 8
# 83             15000                 8
# 84             15000                 8
# 85             15000                 8
# 86             15000                 8
# 87             15000                 8
# 88             15000                 8
# 89             15000                 8
# 90             15000                 8
# 91             15000                 8
# 92             15000                 8
# 98             15000                 8
# 99             15000                 8
# 100            15000                 8
# 101            15000                 8
# 102            15000                 8
# 104            15000                 8
# 105            15000                 8
# 106            15000                 8
# 107            15000                 8
# 108            15000                 8
# 110            15000                 8
# 113            15000                 8
# 114            15000                 8
# 115            15000                 8
# 119            15000                 8
# 127            15000                 8
# 128            15000                 8
# 130            15000                 8
# 131            15000                 8
